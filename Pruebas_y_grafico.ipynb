# %%
import json

class Nodo:
  def __init__(self,idx,lat,lon):
    l_idx =idx.replace('node/','')
    l_idx = int(l_idx)//10000
    self.idx = l_idx
    self.lat = lat
    self.lon = lon
  
  

Nodos = []

with open('mayorazgo.geojson') as f:
    data = json.load(f)


for feature in data['features']:
    Nodos.append(Nodo(feature['id'],feature['geometry']['coordinates'][0],feature['geometry']['coordinates'][1]))
  #print(feature['id'],feature['geometry']['coordinates'])

for nodo in Nodos:
  print(nodo.idx,nodo.lat,nodo.lon)
# Out:
# 47106 -76.9608298 -12.0626269
# 47106 -76.9517659 -12.0602871
# 47106 -76.9516212 -12.0602221
# 50371 -76.945586 -12.0544915
# 127346 -76.9442583 -12.0559242
# 127356 -76.9429703 -12.0529124
# 127358 -76.9429095 -12.0546824
# 127369 -76.9409226 -12.0542831
# 127373 -76.9501399 -12.0595184
# 127374 -76.9432165 -12.0550605
# 127379 -76.9435809 -12.0547435
# 127380 -76.9440877 -12.0542397
# 127383 -76.9448454 -12.0541172
# 127392 -76.9443037 -12.0538478
# 127392 -76.9425771 -12.0526059
# 127393 -76.943223 -12.0510547
# 127397 -76.9426578 -12.0532547
# 157475 -76.9417652 -12.0531953
# 157475 -76.9411633 -12.0537481
# 157475 -76.9587665 -12.0618716
# 157475 -76.9415861 -12.0528803
# 157475 -76.9416788 -12.0534669
# 157475 -76.9513395 -12.0601002
# 157475 -76.9417872 -12.0530477
# 157475 -76.937883 -12.0449347
# 157475 -76.9428899 -12.0509415
# 157475 -76.9428574 -12.055381
# 157475 -76.941877 -12.0527756
# 157475 -76.9444388 -12.0565738
# 157475 -76.9408228 -12.0531253
# 157475 -76.9590268 -12.0619679
# 157475 -76.9447228 -12.0567087
# 157475 -76.941326 -12.0528324
# 157696 -76.9550479 -12.0613997
# 172496 -76.9423079 -12.0555981
# 172496 -76.9401827 -12.0546787
# 172614 -76.9433542 -12.0531959
# 172614 -76.943578 -12.0516968
# 172614 -76.9450469 -12.0527288
# 172614 -76.9436768 -12.0539831
# 172614 -76.9446815 -12.0561455
# 172614 -76.9446708 -12.0534895
# 172614 -76.9420221 -12.0530661
# 172614 -76.9436288 -12.0527668
# 172614 -76.9444751 -12.0464709
# 172614 -76.9437146 -12.0512507
# 172614 -76.94507 -12.0537057
# 172614 -76.9440011 -12.0518525
# 172614 -76.9411198 -12.0536685
# 172614 -76.9408781 -12.0532264
# 172614 -76.9472088 -12.0579755
# 172614 -76.943857 -12.0522605
# 172614 -76.9422793 -12.0535087
# 338396 -76.9563763 -12.0615588
# 403229 -76.9435177 -12.0490917
# 404478 -76.9443201 -12.0468953
# 417242 -76.9522567 -12.0605002
# 435663 -76.9603418 -12.0624451
# 447534 -76.9468407 -12.0577824
# 468217 -76.9449847 -12.0568465
# 571178 -76.9518643 -12.0603292
# 941035 -76.9464934 -12.0576063
# 538061 -76.9413423 -12.0540668
# 549175 -76.9439131 -12.0535796
# 756621 -76.9408249 -12.0531176
# 571242 -76.9419138 -12.0531193
# 432220 -76.9434597 -12.0492551

# %%
from graphviz.backend import version
import numpy as np
import graphviz as gv
import json

class Nodo:
  def __init__(self,idx,lat,lon):
    l_idx =idx.replace('node/','')
    self.idx = l_idx
    self.lat = lat
    self.lon = lon
  def Return_idx(self):
    return self.idx
  def Return_Para_Print(self):
    return self.idx,self.lat,self.lon

Nodos = []

with open('parte_ohio.geojson') as f:
    data = json.load(f)


for feature in data['features']:
    Nodos.append(Nodo(feature['id'],feature['geometry']['coordinates'][0],feature['geometry']['coordinates'][1]))
  #print(feature['id'],feature['geometry']['coordinates'])

for Nodo in range(30):
  print(Nodos[Nodo].Return_idx(), Nodos[Nodo].lat, Nodos[Nodo].lon)
  #Solo está mostrando los 30 primeros 

graph = gv.Digraph("Prueba")
for u in range(len(Nodos)):
  graph.node(str(u),Nodos[u].Return_idx())

#print(graph)
#graph
# Out:
# 229578283 -82.894021 39.95785
# 229578298 -82.892418 39.95783
# 229579971 -82.860981 39.981649
# 229581201 -82.8786511 39.9374021
# 229581209 -82.879601 39.937244
# 229582719 -82.882739 39.975551
# 229582742 -82.884522 39.97571
# 229584045 -82.938498 39.988188
# 229585478 -82.853434 39.979549
# 229585512 -82.853493 39.982474
# 229585539 -82.853041 39.984205
# 229588240 -82.930094 39.999641
# 229595614 -82.9010932 39.9383279
# 229597736 -82.862273 40.002682
# 229597785 -82.862123 40.003016
# 229600965 -82.856906 39.984752
# 229600994 -82.855258 39.980825
# 229601047 -82.852876 39.977346
# 229603012 -82.855506 39.982253
# 229603054 -82.850061 39.978046
# 229604581 -82.9335843 39.9946544
# 229605306 -82.9414465 39.9435093
# 229605319 -82.852303 39.976267
# 229605335 -82.854564 39.977938
# 229605340 -82.854611 39.978435
# 229605343 -82.85424 39.979222
# 229605351 -82.853297 39.979799
# 229605355 -82.851557 39.979735
# 229606616 -82.851198 39.97576
# 229606631 -82.8477481 39.9726987
